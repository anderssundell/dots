# %% [markdown]
# # A test of an interactive notebook
#
# In this notebook we will see how it works to run something interactively.
# We will try to produce some graphs in R. First we do a super simple graph where we create the data directly.

# %%
# A simple graph
varx <- c(4, 7, 10, 40, 54)
vary <- c(3, 5, 12, 25, 30)
df <- as.data.frame(cbind(varx, vary))
plot(df)
# Out:
# plot without title

# %% [markdown]
# ## Loading QoG data
# Now let's try something more interesting. We will load the QoG dataset from the web, and try to plot something. But first let's load the tidyverse package.

# %%
library(ggplot2)

# %%
data <- read_csv("http://www.qogdata.pol.gu.se/data/qog_bas_cs_jan20.csv")
# Out:
# Parsed with column specification:
# cols(
#   .default = col_double(),
#   cname = col_character(),
#   ccodealp = col_character(),
#   version = col_character()
# )
#
# See spec(...) for full column specifications.

# %%
ggplot(data, aes(x=p_polity2, y=ti_cpi)) +
    geom_point(col="blue")
# Out:
# Warning message:
# “Removed 30 rows containing missing values (geom_point).”
# plot without title

# %%
ggplot(data, aes(x=p_polity2)) +
    geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# Warning message:
# “Removed 29 rows containing non-finite values (stat_bin).”
# plot without title
