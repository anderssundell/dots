# %% [markdown]
# # A test of an interactive notebook
#
# In this notebook we will see how it works to run something interactively.
# We will try to produce a graph in R.

# %%
# X variable
varx <- c(4, 7, 10, 40, 54)
vary <- c(3, 5, 12, 25, 30)
df <- as.data.frame(cbind(varx, vary))
plot(df)
# Out:
# plot without title
